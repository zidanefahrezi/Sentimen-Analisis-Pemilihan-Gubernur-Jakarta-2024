# %%
import os

name = "All_dataset"

# Tentukan nama folder yang ingin dibuat
nama_folder = "/content/"+name+"/"

# Buat folder baru
os.makedirs(nama_folder, exist_ok=True)

print(f"Folder '{nama_folder}' berhasil dibuat.")
# Out:
# Folder '/content/All_dataset/' berhasil dibuat.

# %%
import pandas as pd
import os

# Folder tempat file CSV berada
folder_path = nama_folder

# Membaca semua file CSV dalam folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Membaca dan menggabungkan semua file CSV
dataframes = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Menggabungkan semua DataFrame menjadi satu
combined_df = pd.concat(dataframes, ignore_index=True)

# Menyimpan dataset gabungan ke file baru
output_file = "/content/"+name+"_dataset.csv"
combined_df.to_csv(output_file, index=False)

print(f"Dataset berhasil digabungkan dan disimpan ke {output_file}")
# Out:
# Dataset berhasil digabungkan dan disimpan ke /content/All_dataset_dataset.csv

# %%
import pandas as pd

# Contoh DataFrame

df = pd.read_csv(output_file)

# Menghapus duplikat berdasarkan kolom 'Nama'
df_unique = df.drop_duplicates(subset=['full_text'])

print("DataFrame tanpa duplikat berdasarkan kolom 'Nama':")
df_unique.to_csv("/content/"+name+"_duplicate_dataset.csv", index=False)
# Out:
# DataFrame tanpa duplikat berdasarkan kolom 'Nama':
# <ipython-input-29-159636ced873>:5: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(output_file)

# %%
df_unique.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1838233736028319849  Mon Sep 23 15:07:30 +0000 2024           14643
# 1  1828782991453339727  Wed Aug 28 13:13:36 +0000 2024            5610
# 2  1828006841726726316  Mon Aug 26 09:49:28 +0000 2024           16869
# 3  1853248247298654224  Mon Nov 04 01:29:48 +0000 2024               3
# 4  1854003557588230235  Wed Nov 06 03:31:08 +0000 2024               7
#
#                                            full_text               id_str  \
# 0  ‼️𝗦𝗔𝗛‼️ Paslon cagub-cawagub DKJ baru aja ngam...  1838233736028319849
# 1  Selamat berjuang Pak Pramono &amp; Bang Rano! ...  1828782991453339727
# 2  Kalau besok Megawati tetep ngotot Pramono Anun...  1828006841726726316
# 3  Ibu Sinta Nuriyah istri Presiden Keempat Repub...  1853248247298654224
# 4  Pasangan Calon Gubernur DKI Jakarta Pramono-Ra...  1854003557588230235
#
#                                            image_url in_reply_to_screen_name  \
# ...

# %%
import pandas as pd

# %%
name = "Pramono_1200"

# %%
df = pd.read_csv("/content/Pramono_all_duplicate_dataset.csv")

# %%
df = df.sample(n=1200, random_state=42)

# %%
df.to_csv("/content/"+name+"_duplicate_dataset.csv", index=False)
